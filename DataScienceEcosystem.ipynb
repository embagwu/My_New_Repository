# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Title: DataScienceEcosystem.ipynb

# %% [markdown]
# Introduction: This program accomplishe final project for Tools for Data Science

# %% [markdown]
# Data science languages are Python, R, SQL

# %% [markdown]
# Data science libraries include plotlib, numpy, panda

# %% [markdown]
# |Data science Tools Table |
# --------------------------
# |Item No| Tool Name |
# |   1   | GitHub    |
# |   2   | Python    |
# |   3   | Jupiter Notebook|

# %% [markdown]
# Arithmetic Expression

# %%
 5*50 +55*70

# %%
Hrs = minutes/60

# %% [markdown]
# Objectives:
# * Demonstrate use of markdown
# * Demonstrate use of code
# * Demonstrate understanding of data science

# %% [markdown]
# Author's name is Emmanuel Mbagwu
